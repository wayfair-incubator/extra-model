# %%
import pandas as pd
df = pd.read_csv('../../../tests/resources/100_comments.csv')
df
# Out:
#                                              Comments  CommentId
# 0   My salad had a bland vinegrette on the baby gr...        561
# 1                            Appetite instantly gone.        997
# 2                   The only downside is the service.        321
# 3           We waited for forty five minutes in vain.        153
# 4   It took over 30 min to get their milkshake, wh...         74
# ..                                                ...        ...
# 95  You get incredibly fresh fish, prepared with c...        296
# 96                            I give it 2 thumbs down        149
# 97                              AN HOUR... seriously?        569
# 98  On the up side, their cafe serves really good ...        100
# 99  Del Taco is pretty nasty and should be avoided...        965
#
# [100 rows x 2 columns]

# %% [markdown]
# ### We can pass is_dataframe=True and pass input_path as a dataframe

# %%
from extra_model._run import run
from pathlib import Path

run(input_path = df, is_dataframe = True, embeddings_path='../../../embeddings')
# Out:
# /usr/lib/python3.9/site-packages/extra_model-0.3.0-py3.9.egg/extra_model/_disambiguate.py:111: RuntimeWarning: invalid value encountered in true_divide
#   contexts = [np.divide(context, np.linalg.norm(context)) for context in contexts]
#     Position       Aspect Descriptor  AspectCount    WordnetNode  \
# 0          9     downside       only            1  downside.n.01
# 1         65        chips       many            1      chip.n.04
# 2         77        treat       real            1    dainty.n.01
# 3         33         food   mediocre            4      food.n.01
# 4          6         food      Worst            4      food.n.01
# ..       ...          ...        ...          ...            ...
# 72        51         trap        old            1      trap.n.02
# 73        51  grease trap        old            1      trap.n.02
# 74        24        piece       long            1     piece.n.06
# 75        71          bit     little            1       bit.n.05
# ...
